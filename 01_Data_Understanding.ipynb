# %% [markdown]
# # AI-Powered Healthcare Claims Scrubbing & Denial Prediction
#
# ## Notebook 01 – Data Understanding
#
# ### Objective
#
# The objective of this notebook is to understand the healthcare claims dataset before building machine learning models.
#
# This notebook performs:
#
# - Dataset loading
# - Initial exploration
# - Schema validation
# - Data quality assessment
# - Business understanding of each feature
# - Target variable inspection
#
# The findings from this notebook will guide feature engineering, rule-based claim scrubbing, denial prediction, and CARC denial reason prediction.

# %% [markdown]
# ## Liberies

# %%
import pandas as pd

# %%
claims = pd.read_csv(r"rcm_claims_hard_synthetic.csv")
print(claims.head())
# Out:
#     Claim_ID Claim_Form_Type  Provider_NPI Provider_Specialty     Payer  \
# 0  CLM100000            837P    3579337979        Orthopedics  Medicare
# 1  CLM100001            837I    9409175431  Internal Medicine  Medicaid
# 2  CLM100002            837P    1396263773          Radiology  Medicaid
# 3  CLM100003            837I    8670024292        Orthopedics     Aetna
# 4  CLM100004            837I    7425344331        Orthopedics  Medicare
#
#    Place_of_Service_Code Place_of_Service_Desc Diagnosis_Code  Procedure_Code  \
# 0                     23        Emergency Room            I10           29881
# 1                     21    Inpatient Hospital          J18.9           36415
# 2                     11                Office          E78.5           99213
# 3                     22   Outpatient Hospital          M54.5           93000
# 4                     21    Inpatient Hospital          K21.9           99213
#
#                  Procedure_Desc  ... Eligibility_Verified  \
# ...

# %%
claims.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 28 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Claim_ID                           15000 non-null  str
#  1   Claim_Form_Type                    15000 non-null  str
#  2   Provider_NPI                       15000 non-null  int64
#  3   Provider_Specialty                 15000 non-null  str
#  4   Payer                              15000 non-null  str
#  5   Place_of_Service_Code              15000 non-null  int64
#  6   Place_of_Service_Desc              15000 non-null  str
#  7   Diagnosis_Code                     15000 non-null  str
#  8   Procedure_Code                     15000 non-null  int64
#  9   Procedure_Desc                     15000 non-null  str
#  10  Modifier_Code                      6726 non-null   str
#  11  Billed_Amount                      15000 non-null  float64
# ...

# %%
claims.isnull().sum()
# Out:
# Claim_ID                                 0
# Claim_Form_Type                          0
# Provider_NPI                             0
# Provider_Specialty                       0
# Payer                                    0
# Place_of_Service_Code                    0
# Place_of_Service_Desc                    0
# Diagnosis_Code                           0
# Procedure_Code                           0
# Procedure_Desc                           0
# Modifier_Code                         8274
# Billed_Amount                            0
# Service_Date                             0
# Claim_Submission_Date                    0
# Days_to_Submission                       0
# Payer_Timely_Filing_Limit_Days           0
# Prior_Auth_Required                      0
# Prior_Auth_Obtained                      0
# Eligibility_Verified                     0
# Duplicate_Claim_Flag                     0
# NCCI_Bundling_Flag                       0
# Clearinghouse_Validation_Passed          0
# ...

# %%
claims.describe().T
# Out:
#                                      count          mean           std  \
# Provider_NPI                       15000.0  5.477129e+09  2.592831e+09
# Place_of_Service_Code              15000.0  1.698193e+01  5.498353e+00
# Procedure_Code                     15000.0  6.991901e+04  2.765791e+04
# Billed_Amount                      15000.0  3.115481e+03  6.557852e+03
# Days_to_Submission                 15000.0  2.271633e+01  4.414894e+01
# Payer_Timely_Filing_Limit_Days     15000.0  1.947737e+02  1.132107e+02
# Provider_Monthly_Claim_Volume      15000.0  1.532725e+02  8.475786e+01
# Provider_Payer_Prior_Denial_Count  15000.0  1.200667e+00  1.083672e+00
#
#                                             min           25%           50%  \
# Provider_NPI                       1.000368e+09  3.224066e+09  5.472660e+09
# Place_of_Service_Code              1.100000e+01  1.100000e+01  2.100000e+01
# Procedure_Code                     2.744700e+04  3.641500e+04  7.214800e+04
# ...

# %%
claims.duplicated().sum()
# Out:
# np.int64(0)

# %%
claims.nunique().sort_values()
# Out:
# Claim_Form_Type                          2
# Claim_Status                             2
# Clearinghouse_Validation_Passed          2
# NCCI_Bundling_Flag                       2
# Duplicate_Claim_Flag                     2
# Eligibility_Verified                     2
# Prior_Auth_Obtained                      2
# Prior_Auth_Required                      2
# Chronic_Condition_Flag                   2
# Payer_Timely_Filing_Limit_Days           3
# Place_of_Service_Desc                    4
# Place_of_Service_Code                    4
# Modifier_Code                            4
# Payer                                    7
# Provider_Specialty                       8
# CARC_Code                                8
# Denial_Reason                            8
# Provider_Payer_Prior_Denial_Count        8
# Procedure_Desc                          10
# Procedure_Code                          10
# Diagnosis_Code                          12
# Days_to_Submission                     281
# ...

# %%
claims['Claim_Status'].value_counts()
# Out:
# Claim_Status
# Approved    12290
# Denied       2710
# Name: count, dtype: int64

# %%
# Percentage of each class
claims["Claim_Status"].value_counts(normalize=True) * 100
# Out:
# Claim_Status
# Approved    81.933333
# Denied      18.066667
# Name: proportion, dtype: float64

# %% [markdown]
# ## unbalanced
# Approved: 12,290 claims (81.93%)
# Denied: 2,710 claims (18.07%)

# %%
claims.to_csv("claims.csv", index=False)
